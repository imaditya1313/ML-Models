# %%
import pandas as pd
import numpy as np

# %%
mushroom = pd.read_csv("mushrooms.csv")

# %%
mushroom
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
independent = pd.DataFrame(data = mushroom.drop(["class"], axis =1))

# %%
independent
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
dependent = pd.DataFrame(data = mushroom['class'])

# %%
dependent
# Out:
#      class
# 0        p
# 1        e
# 2        e
# 3        p
# 4        e
# ...    ...
# 8119     e
# 8120     e
# 8121     e
# 8122     p
# 8123     e
#
# [8124 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
l1 = LabelEncoder()
l2 = LabelEncoder()
l3 = LabelEncoder()
l4 = LabelEncoder()
l5 = LabelEncoder()
l6 = LabelEncoder()
l7 = LabelEncoder()
l8 = LabelEncoder()
l9 = LabelEncoder()
l10 = LabelEncoder()
l11 = LabelEncoder()
l12 = LabelEncoder()
l13 = LabelEncoder()
l14 = LabelEncoder()
l15 = LabelEncoder()
l16 = LabelEncoder()
l17 = LabelEncoder()
l18 = LabelEncoder()
l19 = LabelEncoder()
l20 = LabelEncoder()
l21 = LabelEncoder()
l22 = LabelEncoder()

# %%
independent['cap-shape'] = l1.fit_transform(independent['cap-shape'])
independent['cap-surface'] = l2.fit_transform(independent['cap-surface'])
independent['cap-color'] = l3.fit_transform(independent['cap-color'])
independent['bruises'] = l4.fit_transform(independent['bruises'])
independent['odor'] = l5.fit_transform(independent['odor'])
independent['gill-attachment'] = l6.fit_transform(independent['gill-attachment'])
independent['gill-spacing'] = l7.fit_transform(independent['gill-spacing'])
independent['gill-size'] = l8.fit_transform(independent['gill-size'])
independent['gill-color'] = l9.fit_transform(independent['gill-color'])
independent['stalk-shape'] = l10.fit_transform(independent['stalk-shape'])
independent['stalk-root'] = l11.fit_transform(independent['stalk-root'])
independent['stalk-surface-above-ring'] = l12.fit_transform(independent['stalk-surface-above-ring'])
independent['stalk-surface-below-ring'] = l12.fit_transform(independent['stalk-surface-below-ring'])
independent['stalk-color-above-ring'] = l13.fit_transform(independent['stalk-color-above-ring'])
independent['stalk-color-below-ring'] = l14.fit_transform(independent['stalk-color-below-ring'])
independent['veil-type'] = l15.fit_transform(independent['veil-type'])
independent['veil-color'] = l16.fit_transform(independent['veil-color'])
independent['ring-number'] = l16.fit_transform(independent['ring-number'])
independent['ring-type'] = l17.fit_transform(independent['ring-type'])
independent['spore-print-color'] = l18.fit_transform(independent['spore-print-color'])
independent['population'] = l19.fit_transform(independent['population'])
independent['habitat'] = l20.fit_transform(independent['habitat'])

# %%
ll = LabelEncoder()
dependent['class'] = ll.fit_transform(dependent['class'])

# %%
independent
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
dependent
# Out:
#       class
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0
# ...     ...
# 8119      0
# 8120      0
# 8121      0
# 8122      1
# 8123      0
#
# [8124 rows x 1 columns]

# %%
independent.isnull().values.any()
# Out:
# False

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent,test_size= 0.25,random_state = 200)

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(X_train, y_train)
DT.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(X_train, y_train)
DT.score(X_test, y_test)
# Out:
# 1.0

# %%
DT.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier(n_neighbors = 5)
model2.fit(X_train,y_train)
model2.score(X_test,y_test)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.9985228951255539
