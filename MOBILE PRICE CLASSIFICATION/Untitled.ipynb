# %%
import pandas as pd
import numpy as np

# %%
mobile_price_train = pd.read_csv("train.csv")
mobile_price_test = pd.read_csv("test.csv")

# %%
independent = mobile_price_train.drop(["price_range"],axis=1)
independent
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
dependent = pd.DataFrame(mobile_price_train['price_range'])
dependent
# Out:
#       price_range
# 0               1
# 1               2
# 2               2
# 3               2
# 4               1
# ...           ...
# 1995            0
# 1996            2
# 1997            3
# 1998            0
# 1999            3
#
# [2000 rows x 1 columns]

# %%
y = mobile_price_test.drop(["id"],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent,test_size= 0.25,random_state = 200)

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(X_train, y_train)
DT.score(, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gf/273yncj54yl6zdb8vt2p68fw0000gn/T/ipykernel_1806/2490171640.py in <module>
#       2 DT = DecisionTreeClassifier()
#       3 DT.fit(X_train, y_train)
# ----> 4 DT.score(y, y_test)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     498         """
#     499         from .metrics import accuracy_score
# --> 500         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     501
#     502     def _more_tags(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %%
merge_price = pd.concat([mobile_price_train,mobile_price_test])
merge_price
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
merge_price1 = merge_price.dropna(axis=1)
merge_price1
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
independent = pd.DataFrame(merge_price1.drop(["battery_power"],axis=1))

# %%
independent
# Out:
#      blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
# 0       0          2.2         0   1       0           7    0.6        188
# 1       1          0.5         1   0       1          53    0.7        136
# 2       1          0.5         1   2       1          41    0.9        145
# 3       1          2.5         0   0       0          10    0.8        131
# 4       1          1.2         0  13       1          44    0.6        141
# ..    ...          ...       ...  ..     ...         ...    ...        ...
# 995     1          1.9         0   0       1          54    0.5        170
# 996     0          1.8         1   0       0          13    0.9        186
# 997     0          1.4         0   1       1           8    0.5         80
# 998     1          0.5         1   0       0          50    0.4        171
# 999     1          0.5         0   4       1          35    0.1        140
#
# ...

# %%
dependent = pd.DataFrame(merge_price1["battery_power"])

# %%
dependent
# Out:
#      battery_power
# 0              842
# 1             1021
# 2              563
# 3              615
# 4             1821
# ..             ...
# 995           1700
# 996            609
# 997           1185
# 998           1533
# 999           1270
#
# [3000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.25,random_state=2000)

# %%
x_train,y_train
# Out:
# (      blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
#  325      0          2.1         1   5       0          25    0.4        115
#  1638     0          2.6         1   3       0           8    0.8        185
#  689      1          0.5         0   5       1          57    0.9        155
#  1517     0          1.4         1   3       0          14    0.7        199
#  1658     1          1.3         1   4       1          42    1.0        162
#  ...    ...          ...       ...  ..     ...         ...    ...        ...
#  1659     1          1.5         1   6       0          61    0.2        196
#  1590     0          0.5         1   1       1          36    0.9         87
#  1230     0          2.7         1   5       1          20    0.4        173
#  840      0          1.6         1   5       1          39    0.8        152
#  998      1          0.5         1   0       0          50    0.4        171
#
# ...

# %%
merge_price1.isnull().values.any()
# Out:
# False

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(x_train,y_train)
DT.score(x_test,y_test)
# Out:
# 0.0

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN = KNeighborsClassifier()
KNN.fit(x_train,y_train)
KNN.score(x_test,y_test)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.0013333333333333333
